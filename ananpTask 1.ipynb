# %% [markdown]
# 1. Write a Python program to sum all the items in a list.

# %%
l=[2,3,4,5,6,3,4,5,6,4,3,2,4,5]
total=(i for i in l)
print(sum(total))

# %% [markdown]
# 2. Write a Python program to get the largest number from a list.

# %%
l=[233,44,35,543,643,436,34,34,525,45]
print("largest element is :",max(l))

# %% [markdown]
# 3. Write a Python program to count the number of strings from a given list of strings. The string length is 2 or more and the first and last characters are the same.
#
# ```
# Sample List : ['abc', 'xyz', 'aba', '1221']
# Expected Result : 2
# ```

# %%
l=['abc','1221']
len(l)

# %% [markdown]
# 4. Write a Python program to remove duplicates from a list.

# %%
l=[2,7,3,4,3,3,3,4,55,6,65,4,43,3]
set(l)

# %% [markdown]
# 5. Write a Python program to check if a list is empty or not.

# %%
l=[6,7]
if l==[]:
  print("list is empty")
else:
  print("list is occupied")

# %% [markdown]
# 6. Write a Python program to filter the list if the length of the character is < 4
#
# ```
# Sample List : ['abc', 'xyz', 'aba', '1221']
# Expected Result: ['abc', 'xyz', 'aba']
# ```

# %%
l=['abc','xyz','aba','1221']
sorted_l=[x for x in l if len(x)<4]
print(sorted_l)

# %% [markdown]
# 7.Write a Python program to find the second largest number in a list.

# %%
l=[1234,2134,435,36,6575,76,6435,543,4565,779,76]
l.sort()
print("second largest number is :",l[-2])

# %% [markdown]
# 8. Write a Python program to reverse a list at a specific location.

# %%
l=[1,2,3,4,5,6,7,8,9]
l.reverse()
l

# %% [markdown]
# 9. Write a Python program to check if a list is a palindrome or not. Return true otherwise false.

# %%
num=[1,2,3,4,4,3,2,1]
def is_palindrome(num):
  return("true" if num==num[::-1]else "false")
is_palindrome(num)

# %% [markdown]
# 10. Write a Python a program to find the union and intersection of two lists.

# %%
l={1,2,3,4}
k={2,3,4,7}
z=l.intersection(k)
print("intersection=",z)
h=l.union(k)
print("union=",h)

# %% [markdown]
# 11.Write a Python script to sort (ascending and descending) a dictionary by value

# %%
thisdict={2:"car",4:"bike",3:"bus",1:"train"}
z=dict(sorted(thisdict.items()))
print("ascending=",z)
x=dict(sorted(z.items(),reverse=1))
print("descending=",x)

# %% [markdown]
# 12. Write a Python script to check whether a given key already exists in a dictionary.

# %%
thisdict={"brand":"ford","model":"mustang","year":"1964","fuel":"diesel","year1":"1897"}
def check(thisdict,key):
  return("key already exists"if key in thisdict else"not exist")
z=input("enter a key:")
n=check(thisdict,z)
print(n)
# Out:
# enter a key:j
# not exist

# %% [markdown]
# 13.Write a Python program to sum all the values in a dictionary.

# %%
d={"a":5, "b":10, "c":15, "d":20, "e":25}
total=sum(d.values())
print(total)

# %% [markdown]
# 14.Write a Python program to create a dictionary with a number and its corresponding square from 1 to input number. And also check if the input number is less than 10
#
# ```
# Eg:
# Input : 3
# Output : {1:1, 2:4, 3:9}
# ```

# %%
def thisdict(n):
    if n < 10:
        square_dict = {i: i**2 for i in range(1, n+1)}
        return square_dict
    else:
        print("Input number should be less than 10.")
        return None

def d():
    try:
        num = int(input("Enter a number: "))
        result = thisdict(num)

        if result is not None:
            print("Dictionary of numbers and their squares:")
            print(result)
    except ValueError:
        print("Please enter a valid number.")

if __name__ == "__main__":
    d()
# Out:
# Enter a number: 9
# Dictionary of numbers and their squares:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81}

# %% [markdown]
# 15.Write a Python program to sort a given dictionary by key.

# %%
hisdict={"brand":"ford","model":"mustang","year":"1964","fuel":"diesel","year1":"1897"}
thisdict.keys()
# Out:
# dict_keys(['brand', 'model', 'year', 'fuel', 'year1'])

# %% [markdown]
# 16.  Write a Python program to create a dictionary from a string.
#
# ```
# Note: Track the count of the letters from the string.
# Sample string : 'learnpython'
# Expected output: {'l': 1, 'e': 1, 'a': 1, 'r': 1, 'n': 2, 'p': 1, 'y': 1, 't': 1, 'h': 1, 'o': 1}
#
# ```

# %%
def create_dict(input_string):
    thisdict = {}
    for char in input_string:
        thisdict[char] = thisdict.get(char, 0) + 1
    return thisdict

def main():
    input_string = input("Enter a string: ")
    result_dict = create_dict(input_string)

    print("Dictionary from the string:")
    print(result_dict)

if __name__ == "__main__":
    main()
# Out:
# Enter a string: happy
# Dictionary from the string:
# {'h': 1, 'a': 1, 'p': 2, 'y': 1}

# %% [markdown]
# 17. Write a Python program to get the top three items in a shop.
#
# ```
# Sample data: {'item1': 45.50, 'item2':35, 'item3': 41.30, 'item4':55, 'item5': 24}
#
# Expected Output:
# item4 55
# item1 45.5
# item3 41.3
# ```

# %%
def get_top_items(data):
    sorted_items = sorted(data.items(), key=lambda x: x[1], reverse=True)
    top_3_items = dict(sorted_items[:3])
    return top_3_items

def main():
    data = {'item1': 45.50, 'item2': 35, 'item3': 41.30, 'item4': 55, 'item5': 24}

    top_items = get_top_items(data)

    print("Top 3 items in the shop:")
    print(top_items)

if __name__ == "__main__":
    main()
# Out:
# Top 3 items in the shop:
# {'item4': 55, 'item1': 45.5, 'item3': 41.3}
